# %%
# !pip install brokenaxes

# %%
from brokenaxes import brokenaxes

# %%
# prompt: a bar plot with y axis as cycle count in millions and x axis inidicating the model (like mobilenetv1, mnist, lenet, VGG16, etc). Each model has 5 cycle counts. the cycle counts are provided by user in an array. also include instruction count for the corresponding cycle count

import matplotlib.pyplot as plt
import numpy as np

# Sample data (replace with your actual data)
models = ['mobilenetv1', 'mnist', 'lenet', 'VGG16', 'resnet18']
cycle_counts_millions = [
    [98.64, 91.98, 83.83, 77.19, 49.20],  # Cycle counts for mobilenetv1
    [8, 9, 11, 7, 10],    # Cycle counts for mnist
    [5, 6, 7, 5, 8],      # Cycle counts for lenet
    [27580.15, 26580, 24580, 20731.12, 14584.13], # Cycle counts for VGG16
    [14, 16, 13, 15, 12]  # Cycle counts for resnet18
]

instruction_counts = [
    [82.70, 76.04, 67.89, 61.25, 47.80], # Instructions for mobilenetv1
    [0.8, 0.9, 1.0, 0.7, 0.95], #Instructions for mnist
    [0.5, 0.6, 0.7, 0.55, 0.8], # Instructions for lenet
    [23000.12, 22000, 19000, 16151.21, 14568.39],  # Instructions for VGG16
    [1.3, 1.5, 1.4, 1.6, 1.1]  # Instructions for resnet18
]

x = np.arange(len(models))  # the label locations
width = 0.15  # the width of the bars

#fig, axes = plt.subplots(len(models), 1, figsize=(12, 6 * len(models)))  # Adjust figure height based on the number of models
# Create a single figure with subplots
fig, axes = plt.subplots(len(models), 1, figsize=(12, 6), sharex=True, sharey=True)  # Adjust figure height based on the number of models

# Iterate through each model and create a subplot
for i, model in enumerate(models):
    ax = axes[i]  # Get the current subplot
    cycle_counts = cycle_counts_millions[i]  # Cycle counts for the current model
    inst_counts = instruction_counts[i]  # Instruction counts for the current model

    rects = ax.bar(x, cycle_counts, width, label=f'v{i}')

    # Add black asterisk inside the bars at the instruction count value
    for j, rect in enumerate(rects):
        inst_count = inst_counts[j]  # Get instruction count for current bar
        ax.text(rect.get_x() + rect.get_width() / 2., inst_count, '*', ha='center', va='center', fontsize=12, color='black')

    ax.set_ylabel('Cycle Count (Millions)')
    #ax.set_xlabel('Cycle')
    ax.set_title(f'Cycle Counts for {model}')
    ax.set_xticks(x)
    ax.set_xticklabels([f'Cycle {j + 1}' for j in range(len(cycle_counts))])
    #ax.legend()

# Only show x-axis labels on the bottom subplot
plt.setp(axes[:-1], xticklabels=[])

# Single legend for all subplots
handles, labels = axes[0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper right')
plt.tight_layout()  # Adjust spacing between subplots
plt.xlabel('Cycle')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data (replace with your actual data)
models = ['mobilenetv1', 'mnist', 'lenet', 'VGG16', 'resnet18']
cycle_counts_millions = [
    [98.64, 91.98, 83.83, 77.19, 49.20],  # Cycle counts for mobilenetv1
    [8, 9, 11, 7, 10],    # Cycle counts for mnist
    [5, 6, 7, 5, 8],      # Cycle counts for lenet
    [27580.15, 26580, 24580, 20731.12, 14584.13], # Cycle counts for VGG16
    [14, 16, 13, 15, 12]  # Cycle counts for resnet18
]

instruction_counts = [
    [82.70, 76.04, 67.89, 61.25, 47.80], # Instructions for mobilenetv1
    [0.8, 0.9, 1.0, 0.7, 0.95], #Instructions for mnist
    [0.5, 0.6, 0.7, 0.55, 0.8], # Instructions for lenet
    [23000.12, 22000, 19000, 16151.21, 14568.39],  # Instructions for VGG16
    [1.3, 1.5, 1.4, 1.6, 1.1]  # Instructions for resnet18
]

# ...
x = np.arange(len(cycle_counts_millions[0]))  # x-axis will now represent cycles for each model
width = 0.15  # Reduced width

# Create a single figure with subplots in a 2x3 grid
fig, axes = plt.subplots(2, 3, figsize=(9, 6), sharex=True)  # Adjust figsize as needed

# Flatten the axes array for easier iteration
axes = axes.flatten()

# Iterate through each model and create a subplot
for i, model in enumerate(models):
    ax = axes[i]  # Get the current subplot

    # Check if there are more models than subplots
    if i >= len(axes):
        break  # Stop if we've used all subplots

    cycle_counts = cycle_counts_millions[i]  # Cycle counts for the current model
    inst_counts = instruction_counts[i]  # Instruction counts for the current model

    rects = ax.bar(x, cycle_counts, width, label=f'v{i}')  # Label bars as v0, v1, etc.

    # Add black asterisk inside the bars at the instruction count value
    for j, rect in enumerate(rects):
        inst_count = inst_counts[j]  # Get instruction count for current bar
        ax.text(rect.get_x() + rect.get_width() / 2., inst_count, '*', ha='center', va='center', fontsize=12, color='black')

    ax.set_ylabel('Cycle Count (Millions)')  # Y-label for all subplots
    ax.set_title(f'Model: v{i}')  # Title for each subplot
    ax.set_xticks(x)
    ax.set_xticklabels([f'Cycle {j + 1}' for j in range(len(cycle_counts))])

# Only show x-axis labels on the bottom row
for ax in axes[:3]:
    ax.set_xticklabels([])

# Adjust layout and add legend
plt.tight_layout()
handles, labels = axes[0].get_legend_handles_labels()  # Get legend handles and labels from the first subplot
fig.legend(handles, labels, loc='upper right')  # Place the legend outside the subplots

# Add an overall x-axis label
fig.text(0.5, 0.01, 'Cycle', ha='center', va='center')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data (replace with your actual data)
models = ['LeNet-5*', 'MobileNetV1','ResNet50', 'VGG16']
cycle_counts_millions = [
    [3.18, 2.89, 2.60, 2.31, 1.59],    # Cycle counts for mnist*
    [98.64, 91.98, 83.63, 76.97, 47.62],  # Cycle counts for mobilenetv1
    [7627.75, 7006.59, 6375.05, 5753.89, 3693.95],  # Cycle counts for resnet50
    [27580.15, 25301.04, 23010.36, 20731.25, 13074.18] # Cycle counts for VGG16
]

instruction_counts = [
    [2.60, 2.31, 2.02, 1.73, 1.40], #Instructions for mnist*
    [82.70, 76.04, 67.69, 61.03, 46.22], # Instructions for mobilenetv1
    [6370.45, 5749.29, 5117.75, 4496.59, 3686.07],  # Instructions for resnet50
    [23000.12, 20721.00, 18430.33, 16151.21, 13058.44]  # Instructions for VGG16
]

# ...
x = np.arange(len(cycle_counts_millions[0]))  # x-axis will now represent cycles for each model
width = 0.3  # Reduced width

# Create a single figure with subplots in a 2x3 grid
fig, axes = plt.subplots(2, 2, figsize=(9, 6), sharex=True)  # Adjust figsize as needed, remove sharey=True

# Flatten the axes array for easier iteration
axes = axes.flatten()

# Define colors for each cycle (v0, v1, v2, v3, v4)
#colors = ['blue', 'green', 'red', 'cyan', 'magenta']
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd']  # Example color palette

# Iterate through each model and create a subplot
for i, model in enumerate(models):
    ax = axes[i]  # Get the current subplot

    # Check if there are more models than subplots
    if i >= len(axes):
        break  # Stop if we've used all subplots

    cycle_counts = cycle_counts_millions[i]  # Cycle counts for the current model
    inst_counts = instruction_counts[i]  # Instruction counts for the current model

    # Create bars with different colors for each cycle
    for j, count in enumerate(cycle_counts):
        rects = ax.bar(x[j], count, width, label=f'v{j}', color=colors[j])

        # Add black asterisk inside the bars at the instruction count value
        inst_count = inst_counts[j]  # Get instruction count for current bar
        ax.text(rects[0].get_x() + rects[0].get_width() / 2., inst_count, 'x', ha='center', va='center', fontsize=12, color='black')


    ax.set_title(f'{model}')  # Title for each subplot as model name
    ax.set_xticks([])  # Remove x-axis tick labels

# Adjust layout and add legend
plt.tight_layout()
handles, labels = axes[0].get_legend_handles_labels()  # Get legend handles and labels from the first subplot

# Filter legend to show only one entry for each cycle (v0, v1, v2, v3, v4)
filtered_handles = []
filtered_labels = []
for handle, label in zip(handles, labels):
    if label not in filtered_labels:
        filtered_handles.append(handle)
        filtered_labels.append(label)

import matplotlib.text as mtext
import matplotlib.lines as mlines
#asterisk_handle = mtext.Text(0, 0, '*', fontsize=12, color='black')  # Use Text to create the asterisk
proxy_artist = mlines.Line2D([], [], color='black', marker='x', linestyle='None', markersize=7)

filtered_handles.append(proxy_artist)
filtered_labels.append("Instruction Count")
#fig.legend(filtered_handles, filtered_labels, loc='upper right', bbox_to_anchor=(1.05, 1))  # Place the legend outside the subplots
fig.legend(filtered_handles, filtered_labels, loc='upper right', bbox_to_anchor=(1.07, 1.17), borderaxespad=0)


# Shared y-axis label
fig.text(-0.02, 0.5, 'Cycle Count (Million)', va='center', rotation='vertical') # move the label to extreme left

plt.savefig('cycle_and_instruction_count.eps', format='eps')
plt.show()
# Out:
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data (replace with your actual data)
models = ['LeNet-5*', 'MobileNetV1', 'ResNet50', 'VGG16']
processor_versions = ['v0', 'v1', 'v2', 'v3', 'v4']
cycle_counts_millions = [
    [3.18, 2.89, 2.60, 2.31, 1.59],    # Cycle counts for mnist*
    [98.64, 91.98, 83.63, 76.97, 47.62],  # Cycle counts for mobilenetv1
    [7627.75, 7006.59, 6375.05, 5753.89, 3693.95],  # Cycle counts for resnet50
    [27580.15, 25301.04, 23010.36, 20731.25, 13074.18] # Cycle counts for VGG16
]

instruction_counts = [
    [2.60, 2.31, 2.02, 1.73, 1.40], #Instructions for mnist*
    [82.70, 76.04, 67.69, 61.03, 46.22], # Instructions for mobilenetv1
    [6370.45, 5749.29, 5117.75, 4496.59, 3686.07],  # Instructions for resnet50
    [23000.12, 20721.00, 18430.33, 16151.21, 13058.44]  # Instructions for VGG16
]



# Set the width of the bars
width = 0.35

# Set the positions of the bars on the x-axis
x = np.arange(len(processor_versions))

# Create the figure and axes object
fig, ax = plt.subplots(figsize=(10,6))

# Plot the bars
rects1 = ax.bar(x - width/2, cycle_counts_millions[0], width, label='Cycle Count') # Cycle count bars
rects2 = ax.bar(x + width/2, instruction_counts[0], width, label='Instruction Count') # Instruction count bars

# Add labels, title, and legend
ax.set_xlabel('Processor Version')
ax.set_ylabel('Count (Millions)')
#ax.set_title('Cycle Count and Instruction Count for Different Processor Versions')
ax.set_xticks(x)
ax.set_xticklabels(processor_versions)
ax.legend()

#To see the output, run the code.

# %%
import matplotlib.pyplot as plt
import numpy as np

processor_versions = ['v0', 'v1', 'v2', 'v3', 'v4']
cycle_counts_millions = {
    'Bert-tiny': [1494.934, 1480.247, 1479.18, 1374.457, 700.24],
    'Mobilbert': [67165.631, 66913.646, 66926.65, 61621.331, 47505.581],
    'electra': [32885.277, 32709.034, 32696.33, 30224.392, 14976.732]
}

improvement = {}
for test_case, cycle_counts in cycle_counts_millions.items():
    improvement[test_case] = []
    for i in range(len(processor_versions)):
      if i==0:
        reduction = 100;
      else:
        reduction = ((cycle_counts[i])/ cycle_counts[0])*100
      improvement[test_case].append(reduction)

# Create a figure and subplots
fig, axes = plt.subplots(2, 2, figsize=(10, 8), sharex=True)  # 2x2 grid of subplots
axes = axes.flatten()  # Flatten the axes array for easier iteration

# Plot each test case in a separate subplot
for i, (test_case, improvement_values) in enumerate(improvement.items()):
    ax = axes[i]
    ax.plot(processor_versions, improvement_values, marker='o', linestyle='-')
    ax.set_title(f"{test_case}")

# Set common labels
fig.text(0.5, -0.02, 'Processor Version', ha='center')  # x-axis label
fig.text(-0.02, 0.5, '% reduction in cycle count', va='center', rotation='vertical')  # y-axis label

plt.tight_layout()  # Adjust layout for better spacing
plt.savefig('cycle_count_improvement.eps', format='eps')  # Save the figure
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data (replace with your actual data)
models = ['Bert-Tiny', 'MobileBert', 'Electra', 'KWT-Tiny']
processor_versions = ['v0', 'v1', 'v2', 'v3', 'v4']
cycle_counts_millions = [
    [1494.934, 1480.247, 1374.466, 1374.457, 700.24],    # Cycle counts for Bert-Tiny
    [67165.631, 66913.646, 61595.747, 61621.331, 47505.581],  # Cycle counts for MobileBert
    [32885.277, 32709.034, 30224.502, 30224.392, 14976.732],  # Cycle counts for Electra
    [14.288, 14.13, 14.014, 13.794, 13.569] # Cycle counts for KWT-Tiny
]

instruction_counts = [
    [1294.208, 1279.522, 1173.741, 1173.731, 687.176], #Instructions for Bert-Tiny
    [57540.332, 57288.348, 51970.449, 51996.033, 41914.403], # Instructions for MobileBert
    [28294.688, 28118.445, 25633.913, 25633.803, 14763.608],  # Instructions for Electra
    [11.937, 11.778,	11.662, 11.416, 11.272]  # Instructions for KWT-Tiny
]

# Set the width of the bars
width = 0.35

# Set the positions of the bars on the x-axis
x = np.arange(len(processor_versions))

# Create subplots for each model
fig, axes = plt.subplots(2, 2, figsize=(28, 22), sharex=True)  # 2x2 grid
axes = axes.flatten()

# Iterate through each model and create a subplot
for i, model in enumerate(models):
    ax = axes[i]

    # Plot the bars for the current model
    rects1 = ax.bar(x - width/2, cycle_counts_millions[i], width, label='Cycle Count')
    rects2 = ax.bar(x + width/2, instruction_counts[i], width, label='Instruction Execution Count')

    # Add labels and title for the subplot
    #ax.set_ylabel('Count (Millions)')
    #ax.set_title(model, fontsize=18)
    ax.set_xticks(x)
    ax.set_xticklabels(processor_versions, fontsize=20)
    ax.tick_params(axis='y', labelsize=20)
    ax.legend(fontsize=24)
    # if(model == 'LeNet-5*' or model == 'MobileNetV1' or model == 'ResNet50' or model == 'VGG16'):
    #   ax.text(0.5, -0.06, f"{model}", ha='center', fontsize=24, transform=ax.transAxes)
    # else:
    #   ax.text(0.5, -0.12, f"{model}", ha='center', fontsize=24, transform=ax.transAxes)


# Add a common x-axis label
fig.text(0.5, -0.02, 'Processor Version', ha='center', fontsize=24)
fig.text(-0.01, 0.5, 'Count (Millions)', va='center', rotation='vertical', fontsize=24)

plt.tight_layout()
plt.savefig('cycle_and_instruction_count.eps', format='eps', bbox_inches='tight')
plt.show()
# Out:
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data (replace with your actual data)
models = ['LeNet-5*', 'MobileNetV1', 'ResNet50', 'VGG16']
processor_versions = ['v0', 'v1', 'v2', 'v3', 'v4']
cycle_counts_millions = [
    [3.18, 2.89, 2.60, 2.31, 1.59],    # Cycle counts for mnist*
    [98.64, 91.98, 83.63, 76.97, 47.62],  # Cycle counts for mobilenetv1
    [7627.75, 7006.59, 6375.05, 5753.89, 3693.95],  # Cycle counts for resnet50
    [27580.15, 25301.04, 23010.36, 20731.25, 13074.18] # Cycle counts for VGG16
]

instruction_counts = [
    [2.60, 2.31, 2.02, 1.73, 1.40], #Instructions for mnist*
    [82.70, 76.04, 67.69, 61.03, 46.22], # Instructions for mobilenetv1
    [6370.45, 5749.29, 5117.75, 4496.59, 3686.07],  # Instructions for resnet50
    [23000.12, 20721.00, 18430.33, 16151.21, 13058.44]  # Instructions for VGG16
]

# Set the width of the bars
width = 0.35

# Set the positions of the bars on the x-axis
x = np.arange(len(processor_versions))

# Create subplots for each model
fig, axes = plt.subplots(2, 2, figsize=(12, 8), sharex=True, sharey=True)  # 2x2 grid, sharex=True, sharey=True added
axes = axes.flatten()

# Iterate through each model and create a subplot
for i, model in enumerate(models):
    ax = axes[i]

    # Plot the bars for the current model
    rects1 = ax.bar(x - width/2, cycle_counts_millions[i], width, label='Cycle Count')
    rects2 = ax.bar(x + width/2, instruction_counts[i], width, label='Instruction Count')

    # Add labels and title for the subplot
    # ax.set_ylabel('Count (Millions)')  # Removed individual y-axis labels
    ax.set_title(model)
    # ax.set_xticks(x)  # Removed individual x-axis ticks
    # ax.set_xticklabels(processor_versions)  # Removed individual x-axis labels
    # ax.legend()  # Removed individual legends

# Add a common x-axis label
fig.text(0.5, 0.04, 'Processor Version', ha='center')

# Add a common y-axis label
fig.text(0.04, 0.5, 'Count (Millions)', va='center', rotation='vertical')

# Add a common legend
handles, labels = axes[0].get_legend_handles_labels()  # Get legend handles and labels from the first subplot
fig.legend(handles, labels, loc='upper right')  # Place the legend outside the subplots

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_acceleration_factors(models, cycle_counts):
  """Plots acceleration factors for multiple models.

  Args:
    models: A list of model names.
    cycle_counts: A list of lists, where each inner list contains
      cycle counts for a model (v0, v1, v2, v3, v4).
  """

  num_models = len(models)
  fig, axes = plt.subplots(2, 2, figsize=(10, 8))  # Create a 2x2 grid of subplots
  axes = axes.flatten()  # Flatten the axes array for easier iteration

  x_labels = ['v0', 'v1', 'v2', 'v3', 'v4']
  for i, model in enumerate(models):
    if i >= len(axes):  # Handle cases with more models than subplots
      break
    ax = axes[i]
    acceleration_factors = [count / cycle_counts[i][0] for count in cycle_counts[i]]  # Normalize to v0

    ax.plot(x_labels, acceleration_factors, marker='o', linestyle='--')  # Plot acceleration factors

    # Format y-axis ticks as multiples of 'x'
    ax.set_yticklabels(['{:.3f}x'.format(tick) for tick in ax.get_yticks()])

   # ax.set_ylabel("Acceleration Factor (v0 = 1x)")
   # ax.set_title(f"Acceleration Factors for {model}")

    # Box the plot
    for spine in ['top', 'bottom', 'left', 'right']:
        ax.spines[spine].set_linewidth(1)

  plt.tight_layout()  # Adjust subplot params for a tight layout
  #plt.show()
  plt.savefig(f'{model}_count.eps', format='eps')

# Example Usage with Provided Data:
models = ['LUT', 'MUX', 'Registers', 'Power']
#models = ['Registers']
cycle_counts = [
    [4492, 5463, 6409, 5845, 6207],
    [905, 904, 912, 910, 910],
    [1923, 1927, 1946, 1938, 2268],
    [830, 852, 850, 847, 849],
]

plot_acceleration_factors(models, cycle_counts)
# Out:
# <ipython-input-6-dad4615a5782>:27: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(['{:.3f}x'.format(tick) for tick in ax.get_yticks()])

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_acceleration_factors(models, cycle_counts):
  """Plots acceleration factors for multiple models.

  Args:
    models: A list of model names.
    cycle_counts: A list of lists, where each inner list contains
      cycle counts for a model (v0, v1, v2, v3, v4).
  """

  num_models = len(models)
  #fig, axes = plt.subplots(2, 2, figsize=(10, 8))  # Create a 2x2 grid of subplots
  #axes = axes.flatten()  # Flatten the axes array for easier iteration

  x_labels = ['v0', 'v1', 'v2', 'v3', 'v4']
  for i, model in enumerate(models):
    #if i >= len(axes):  # Handle cases with more models than subplots
     # break
    #ax = axes[i]
    fig, ax = plt.subplots(figsize=(5, 3.5))  # Create a new figure and axes for each plot
    acceleration_factors = [count / cycle_counts[i][0] for count in cycle_counts[i]]  # Normalize to v0

    ax.plot(x_labels, acceleration_factors, marker='o', linestyle='--')  # Plot acceleration factors

    # Format y-axis ticks as multiples of 'x'
    ax.set_yticklabels(['{:.3f}x'.format(tick) for tick in ax.get_yticks()])

    #ax.set_ylabel("Acceleration Factor (v0 = 1x)")
    #ax.set_title(f"Acceleration Factors for {model}")

    # Box the plot
    for spine in ['top', 'bottom', 'left', 'right']:
        ax.spines[spine].set_linewidth(1)

    plt.tight_layout()  # Adjust subplot params for a tight layout
    #plt.show()
    plt.savefig(f'{model}_count.eps', format='eps')
    plt.close(fig)  # Close the figure to release memory

# Example Usage with Provided Data:
models = ['LUT', 'MUX', 'Registers', 'Power']
#models = ['Registers']
cycle_counts = [
    [4492, 5463, 6409, 5845, 6207],
    [905, 904, 912, 910, 910],
    [1923, 1927, 1946, 1938, 2268],
    [830, 852, 850, 847, 849],
]

plot_acceleration_factors(models, cycle_counts)
# Out:
# <ipython-input-7-ca8e11785bf5>:28: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(['{:.3f}x'.format(tick) for tick in ax.get_yticks()])
# <ipython-input-7-ca8e11785bf5>:28: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(['{:.3f}x'.format(tick) for tick in ax.get_yticks()])
# <ipython-input-7-ca8e11785bf5>:28: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(['{:.3f}x'.format(tick) for tick in ax.get_yticks()])
# <ipython-input-7-ca8e11785bf5>:28: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(['{:.3f}x'.format(tick) for tick in ax.get_yticks()])

# %%
import matplotlib.pyplot as plt
import matplotlib.lines as mlines  # Import for creating custom legend handles
import matplotlib.patches as mpatches # Import for creating custom legend handles


# Sample Data (Replace with your actual data)
versions = ['v0', 'v1', 'v2', 'v3', 'v4']
test_cases = {
    'Test Case 1': {'program': [1512, 1496, 1480, 1468, 1352], 'data': [62292, 32292, 32292, 32292, 32238]},
    'Test Case 2': {'program': [24776, 24708, 23636, 23524, 22404], 'data': [636975, 606975, 606975, 606975, 606975]},
    'Test Case 3': {'program': [40456, 40232, 38852, 38640, 36360], 'data': [45772107, 45742107, 45742107, 45742107, 45742107]},
    'Test Case 4': {'program': [13504, 13532, 13128, 13084, 12612], 'data': [16531598, 16501600, 16501600, 16501600, 16501600]},
}
colors = ['blue', 'green', 'red', 'purple']

plt.figure(figsize=(10, 6))

for i, (test_case, data) in enumerate(test_cases.items()):
    plt.plot(versions, data['program'], marker='^', linestyle='-', color=colors[i], label=f'{test_case} (Program)')
    plt.plot(versions, data['data'], marker='s', linestyle='-', color=colors[i], label=f'{test_case} (Data)')


plt.xlabel("Processor Version")
plt.ylabel("Memory Size (Bytes)")
#plt.title("Program and Data Memory Size Across Processor Versions")

# Place the legend outside the plot area
#plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

# Custom legend handles without colored text for the test case name
handles = [
    mlines.Line2D([], [], color='blue', label='mnist*'),
    mlines.Line2D([], [], color='orange', label='MobileNetV1'),
    mlines.Line2D([], [], color='green', label='ResNet50'),
    mlines.Line2D([], [], color='purple', label='VGG16'),
    mlines.Line2D([], [], color='black', marker='s', linestyle='None', markersize=6, label='Data Memory'),
    mlines.Line2D([], [], color='black', marker='^', linestyle='None', markersize=6, label='Program Memory')
]


labels = [f'Test Case {i+1}' for i in range(len(test_cases))] + [''] * len(test_cases) + ['Data Memory', 'Program Memory']

# Create legend with custom handles and labels
plt.legend(handles=handles, loc='upper right', bbox_to_anchor=(1.24, 1.17), borderaxespad=0)

# Get the legend text and apply the color
texts = legend.get_texts()
for i in range(len(test_cases)):
  texts[i].set_color(colors[i])

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.lines as mlines  # Import for creating custom legend handles
import matplotlib.patches as mpatches # Import for creating custom legend handles


# Sample Data (Replace with your actual data)
versions = ['v0', 'v1', 'v2', 'v3', 'v4']
test_cases = {
    'Test Case 1': {'program': [1512, 1496, 1480, 1468, 1352], 'data': [62292, 32292, 32292, 32292, 32238]},
    'Test Case 2': {'program': [24776, 24708, 23636, 23524, 22404], 'data': [636975, 606975, 606975, 606975, 606975]},
    'Test Case 3': {'program': [40456, 40232, 38852, 38640, 36360], 'data': [45772107, 45742107, 45742107, 45742107, 45742107]},
    'Test Case 4': {'program': [13504, 13532, 13128, 13084, 12612], 'data': [16531598, 16501600, 16501600, 16501600, 16501600]},
}
colors = ['blue', 'green', 'red', 'purple']

plt.figure(figsize=(10, 6))

# Scale the data by dividing by 1024
for test_case, data in test_cases.items():
    data['program'] = [x  for x in data['program']]
    data['data'] = [x  for x in data['data']]

for i, (test_case, data) in enumerate(test_cases.items()):
    plt.plot(versions, data['program'], marker='^', linestyle='-', color=colors[i], label=f'{test_case} (Program)')
    plt.plot(versions, data['data'], marker='s', linestyle='-', color=colors[i], label=f'{test_case} (Data)')


plt.xlabel("Processor Version")
plt.ylabel("Memory Size (kB)")
#plt.title("Program and Data Memory Size Across Processor Versions")

# Place the legend outside the plot area
#plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

# Custom legend handles without colored text for the test case name
handles = [
    mlines.Line2D([], [], color='blue', label='mnist*'),
    mlines.Line2D([], [], color='orange', label='MobileNetV1'),
    mlines.Line2D([], [], color='green', label='ResNet50'),
    mlines.Line2D([], [], color='purple', label='VGG16'),
    mlines.Line2D([], [], color='black', marker='s', linestyle='None', markersize=6, label='Data Memory'),
    mlines.Line2D([], [], color='black', marker='^', linestyle='None', markersize=6, label='Program Memory')
]


labels = [f'Test Case {i+1}' for i in range(len(test_cases))] + [''] * len(test_cases) + ['Data Memory', 'Program Memory']

# Create legend with custom handles and labels
plt.legend(handles=handles, loc='upper right', bbox_to_anchor=(1.24, 1.17), borderaxespad=0)

# Get the legend text and apply the color
texts = legend.get_texts()
for i in range(len(test_cases)):
  texts[i].set_color(colors[i])

plt.tight_layout()
plt.show()

# %%
# prompt: Given 5 processor version v0,v1,v2,v3,v4 and their power numbers in milliwatts. Also, given is the cycle counts in millions of 4 test cases for all the versions of the processor. If the clock freq is 100MHz, plot a line plot showing energy per inference

import matplotlib.pyplot as plt

# Sample data (replace with your actual data)
models = ['mnist*', 'MobileNetV1','ResNet50', 'VGG16']

processor_versions = ['v0', 'v1', 'v2', 'v3', 'v4']
power_milliwatts = [830, 852, 850, 847, 849]  # Example power numbers
cycle_counts_millions = {
    'mnist*': [3.18, 2.89, 2.60, 2.31, 1.59],
    'MobileNetV1': [98.64, 91.98, 83.63, 76.97, 47.62],
    'ResNet50': [7627.75, 7006.59, 6375.05, 5753.89, 3693.95],
    'VGG16': [27580.15, 25301.04, 23010.36, 20731.25, 13074.18]
}

clock_frequency_MHz = 100


# Calculate energy per inference for each test case and processor version
energy_per_inference = {}
for test_case, cycle_counts in cycle_counts_millions.items():
  energy_per_inference[test_case] = []
  for i in range(len(processor_versions)):
    energy = ((cycle_counts[i]/2) * power_milliwatts[i]) / clock_frequency_MHz
    energy_per_inference[test_case].append(energy)

# Plotting
plt.figure(figsize=(10, 6))

for test_case, energy_values in energy_per_inference.items():
    plt.plot(processor_versions, energy_values, marker='o', linestyle='-', label=test_case)

plt.xlabel("Processor Version")
plt.ylabel("Energy per Inference (mJ)")
#plt.title("Energy per Inference for Different Processor Versions")
plt.legend()
#plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data (replace with your actual data)
models = ['mnist*', 'MobileNetV1','ResNet50', 'VGG16']

processor_versions = ['v0', 'v1', 'v2', 'v3', 'v4']
power_milliwatts = [830, 852, 850, 847, 849]  # Example power numbers
cycle_counts_millions = {
    'mnist*': [3.18, 2.89, 2.60, 2.31, 1.59],
    'MobileNetV1': [98.64, 91.98, 83.63, 76.97, 47.62],
    'ResNet50': [7627.75, 7006.59, 6375.05, 5753.89, 3693.95],
    'VGG16': [27580.15, 25301.04, 23010.36, 20731.25, 13074.18]
}

clock_frequency_MHz = 100


# Calculate energy per inference for each test case and processor version
energy_per_inference = {}
for test_case, cycle_counts in cycle_counts_millions.items():
  energy_per_inference[test_case] = []
  for i in range(len(processor_versions)):
    energy = ((cycle_counts[i]/2) * power_milliwatts[i]) / clock_frequency_MHz
    energy_per_inference[test_case].append(energy)

# Plotting
width = 0.15  # the width of the bars
x = np.arange(len(processor_versions))
plt.figure(figsize=(10, 6))

# Create bars for each test case
for i, (test_case, energy_values) in enumerate(energy_per_inference.items()):
  plt.bar(x + i * width, energy_values, width, label=test_case)


plt.xlabel("Processor Version")
plt.ylabel("Energy per Inference (mJ)")
#plt.title("Energy per Inference for Different Processor Versions")

# Set x-axis ticks and labels
plt.xticks(x + width * (len(energy_per_inference) -1)/2, processor_versions) # Center the x-axis ticks

plt.legend()
#plt.grid(True)

# Save the figure in EPS format
plt.savefig('energy_per_inference.eps', format='eps')

plt.show()
# Out:
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data (replace with your actual data)
models = ['mnist*', 'MobileNetV1', 'ResNet50', 'VGG16']

processor_versions = ['v0', 'v1', 'v2', 'v3', 'v4']
power_milliwatts = [830, 852, 850, 847, 849]  # Example power numbers
cycle_counts_millions = {
    'mnist*': [3.18, 2.89, 2.60, 2.31, 1.59],
    'MobileNetV1': [98.64, 91.98, 83.63, 76.97, 47.62],
    'ResNet50': [7627.75, 7006.59, 6375.05, 5753.89, 3693.95],
    'VGG16': [27580.15, 25301.04, 23010.36, 20731.25, 13074.18]
}

clock_frequency_MHz = 100

# Calculate energy per inference for each test case and processor version
energy_per_inference = {}
for test_case, cycle_counts in cycle_counts_millions.items():
    energy_per_inference[test_case] = []
    for i in range(len(processor_versions)):
        energy = ((cycle_counts[i] / 2) * power_milliwatts[i]) / clock_frequency_MHz
        energy_per_inference[test_case].append(energy)

# Create separate line plots for each test case
for test_case, energy_values in energy_per_inference.items():
    plt.figure(figsize=(8, 6))  # Create a new figure for each plot
    plt.plot(processor_versions, energy_values, marker='o', linestyle='-')
    plt.xlabel("Processor Version")
    plt.ylabel("Energy per Inference (mJ)")
    plt.title(f"Energy per Inference for {test_case}")
    #plt.grid(True)
    plt.savefig(f'{test_case}_energy_per_inference.eps', format='eps')  # Save with test case name
    plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data (replace with your actual data)
models = ['mnist*', 'MobileNetV1', 'ResNet50', 'VGG16']

processor_versions = ['v0', 'v1', 'v2', 'v3', 'v4']
power_milliwatts = [830, 852, 850, 847, 849]  # Example power numbers
cycle_counts_millions = {
    'LeNet-5*': [3.18, 2.89, 2.60, 2.31, 1.59],
    'MobileNetV1': [98.64, 91.98, 83.63, 76.97, 47.62],
    'ResNet50': [7627.75, 7006.59, 6375.05, 5753.89, 3693.95],
    'VGG16': [27580.15, 25301.04, 23010.36, 20731.25, 13074.18]
}

clock_frequency_MHz = 100

# Calculate energy per inference for each test case and processor version
energy_per_inference = {}
for test_case, cycle_counts in cycle_counts_millions.items():
    energy_per_inference[test_case] = []
    for i in range(len(processor_versions)):
        energy = ((cycle_counts[i] / 2) * power_milliwatts[i]) / clock_frequency_MHz
        energy_per_inference[test_case].append(energy)

# Create a figure and subplots
fig, axes = plt.subplots(2, 2, figsize=(10, 8), sharex=True)  # 2x2 grid of subplots
axes = axes.flatten()  # Flatten the axes array for easier iteration

# Plot each test case in a separate subplot
for i, (test_case, energy_values) in enumerate(energy_per_inference.items()):
    ax = axes[i]
    ax.plot(processor_versions, energy_values, marker='o', linestyle='-')
    ax.set_title(f"{test_case}")
    #ax.grid(True)  # Add grid if needed
    # You can customize each subplot further here (e.g., set y-axis limits)

# Set common labels
fig.text(0.5, -0.02, 'Processor Version', ha='center')  # x-axis label
fig.text(-0.02, 0.5, 'Energy per Inference (mJ)', va='center', rotation='vertical')  # y-axis label

plt.tight_layout()  # Adjust layout for better spacing
plt.savefig('energy_per_inference_subplots.eps', format='eps')  # Save the figure
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data (replace with your actual data)
models = ['LeNet-5*', 'MobileNetV1', 'ResNet50', 'VGG16']

processor_versions = ['v0', 'v1', 'v2', 'v3', 'v4']
power_milliwatts = [830, 852, 850, 847, 849]  # Example power numbers
cycle_counts_millions = {
    'LeNet-5*': [3.18, 2.89, 2.60, 2.31, 1.59],
    'MobileNetV1': [98.64, 91.98, 83.63, 76.97, 47.62],
    'ResNet50': [7627.75, 7006.59, 6375.05, 5753.89, 3693.95],
    'VGG16': [27580.15, 25301.04, 23010.36, 20731.25, 13074.18],
    'MobileNetV2': [639.97, 594.35, 542.62, 497.58, 319.48],
    'DenseNet121': [5981.81, 5519.55, 5041.24, 4578.98, 2714.46]
}

clock_frequency_MHz = 100

# Calculate energy per inference for each test case and processor version
energy_per_inference = {}
for test_case, cycle_counts in cycle_counts_millions.items():
    energy_per_inference[test_case] = []
    for i in range(len(processor_versions)):
        energy = ((cycle_counts[i] / 2) * power_milliwatts[i]) / clock_frequency_MHz
        energy_per_inference[test_case].append(energy)

# Create a figure and subplots
fig, axes = plt.subplots(3, 2, figsize=(15, 12), sharex=True)  # 2x2 grid of subplots
axes = axes.flatten()  # Flatten the axes array for easier iteration

# Plot each test case in a separate subplot
for i, (test_case, energy_values) in enumerate(energy_per_inference.items()):
    ax = axes[i]
    ax.bar(processor_versions, energy_values,width=0.35)  # Use bar plot instead of plot
    #ax.set_title(f"{test_case}", fontsize=18)
    ax.set_xticks(range(len(processor_versions)))  # Set x-ticks for each subplot
    ax.set_xticklabels(processor_versions, fontsize=16)
    ax.tick_params(axis='y', labelsize=16)
    if(test_case == 'LeNet-5*' or test_case == 'MobileNetV1' or test_case == 'ResNet50' or test_case == 'VGG16'):
      ax.text(0.5, -0.1, f"{test_case}", ha='center', fontsize=18, transform=ax.transAxes)
    else:
      ax.text(0.5, -0.2, f"{test_case}", ha='center', fontsize=18, transform=ax.transAxes)
    #ax.grid(True)  # Add grid if needed
    # You can customize each subplot further here (e.g., set y-axis limits)

# Set common labels
fig.text(0.5, -0.02, 'Processor Version', ha='center', fontsize=18)  # Common x-axis label
fig.text(-0.02, 0.5, 'Energy (mJ)', va='center', rotation='vertical', fontsize=18)  # Common y-axis label

plt.tight_layout()  # Adjust layout for better spacing
plt.savefig('energy_per_inference_subplots.eps', format='eps', bbox_inches='tight')  # Save the figure
plt.show()

# %%
# prompt: 328/328 - 1281s - loss: 0.2639 - accuracy: 0.9111 - val_loss: 0.1135 - val_accuracy: 0.9577 - 1281s/epoch - 4s/step
# Epoch 2/3
# 328/328 - 1274s - loss: 0.0973 - accuracy: 0.9671 - val_loss: 0.0789 - val_accuracy: 0.9721 - 1274s/epoch - 4s/step
# Epoch 3/3
# 328/328 - 1272s - loss: 0.0677 - accuracy: 0.9761 - val_loss: 0.0785 - val_accuracy: 0.9724 - 1272s/epoch - 4s/step
# This is retraining on a pretrained VGG16 model in Keras on imagenet. It is trained to recognise cars or not cars. It is run for 3 epochs. What is the best way to show this in graph?

import matplotlib.pyplot as plt

epochs = [1, 2, 3]
accuracy = [0.9111, 0.9671, 0.9761]
val_accuracy = [0.9577, 0.9721, 0.9724]
loss = [0.2639, 0.0973, 0.0677]
val_loss = [0.1135, 0.0789, 0.0785]

plt.figure(figsize=(5, 3.5))

#plt.subplot(1, 2, 1)
#plt.plot(epochs, accuracy, label='Training Accuracy')
#plt.plot(epochs, val_accuracy, label='Validation Accuracy')
#plt.xlabel('Epoch')
#plt.ylabel('Accuracy')
#plt.title('Training and Validation Accuracy')
#plt.legend()
#plt.grid(True)

#plt.subplot(1, 2, 2)
plt.plot(epochs, loss, label='Training Loss')
plt.plot(epochs, val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.xticks(epochs)
#plt.title('Training and Validation Loss')
plt.legend()
#plt.grid(True)

plt.tight_layout()
plt.savefig('training_val_VGG16.eps', format='eps')  # Save the figure
plt.show()
# Out:
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
import matplotlib.pyplot as plt

epochs = [1, 2, 3]
accuracy = [0.9488, 0.9794, 0.9838]
val_accuracy = [0.3799, 0.3776, 0.9641]
loss = [0.1409, 0.0592, 0.0487]
val_loss = [2.3381, 4.1694, 0.0971]

plt.figure(figsize=(5, 3.5))

#plt.subplot(1, 2, 1)
#plt.plot(epochs, accuracy, label='Training Accuracy')
#plt.plot(epochs, val_accuracy, label='Validation Accuracy')
#plt.xlabel('Epoch')
#plt.ylabel('Accuracy')
#plt.title('Training and Validation Accuracy')
#plt.legend()
#plt.grid(True)

#plt.subplot(1, 2, 2)
plt.plot(epochs, loss, label='Training Loss')
plt.plot(epochs, val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.xticks(epochs)
#plt.title('Training and Validation Loss')
plt.legend(loc='upper right')
#plt.grid(True)

plt.tight_layout()
plt.savefig('training_val_ResNet50.eps', format='eps')  # Save the figure
plt.show()
# Out:
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
import matplotlib.pyplot as plt

epochs = [1, 2, 3]
accuracy = [0.9275, 0.9634, 0.9749]
val_accuracy = [0.9573, 0.9543, 0.9581]
loss = [0.2047, 0.0988, 0.0680]
val_loss = [0.1210, 0.1237, 0.1193]

plt.figure(figsize=(5, 3.5))

#plt.subplot(1, 2, 1)
#plt.plot(epochs, accuracy, label='Training Accuracy')
#plt.plot(epochs, val_accuracy, label='Validation Accuracy')
#plt.xlabel('Epoch')
#plt.ylabel('Accuracy')
#plt.title('Training and Validation Accuracy')
#plt.legend()
#plt.grid(True)

#plt.subplot(1, 2, 2)
plt.plot(epochs, loss, label='Training Loss')
plt.plot(epochs, val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.xticks(epochs)
#plt.title('Training and Validation Loss')
plt.legend(loc='upper right')
#plt.grid(True)

plt.tight_layout()
plt.savefig('training_val_MobileNetV1.eps', format='eps')  # Save the figure
plt.show()
# Out:
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
model_name	mul_add_count	fusedmac_count	blt_cycle_count	add_count	addi_count	mul_count
0	ResNet50	624143510	520880128	1890915164	740882470	1805151250	625601717
1	LeNet-5	395580	288512	923255	403907	683213	395737
2	MobileNet	6662248	6658048	23603606	8168811	25449176	6868130
3	VGG16	2279602152	2279571456	6887290616	2298802039	6900499100	2281306146



model_name	addi_count	addi_addi_count
0	LeNet-5*	683213	288536
1	MobileNet	25449176	8151239
2	ResNet50	1805151250	530995267
3	VGG16	6900499100	2288928117

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for the plots
models = ['LeNet-5*', 'MobileNetV1', 'ResNet50', 'VGG16']
mac_pattern = {
    'add_count': [403907, 8168811, 740882470, 2298802039],
    'mul_count': [395737, 6868130, 625601717, 2281306146],
    'mul_add_count': [395580, 6662248, 624143510, 2279602152]
}
add2i_pattern = {
    'addi_count': [683213, 25449176, 1805151250, 6900499100],
    'addi_addi_count': [288536, 8151239, 530995267, 2288928117]
}
fusedmac_pattern = {
    'add_count': [403907, 8168811, 740882470, 2298802039],
    'addi_count': [683213, 25449176, 1805151250, 6900499100],
    'mul_count': [395737, 6868130, 625601717, 2281306146],
    'fusedmac_count': [288512, 6658048, 520880128, 2279571456]
}

# Function to create a bar plot
def create_bar_plot(data, title):
    x = np.arange(len(models))
    width = 0.2

    fig, ax = plt.subplots(figsize=(10, 6))

    # Create bars for each category
    for i, (category, values) in enumerate(data.items()):
        ax.bar(x + i * width, values, width, label=category)

    ax.set_ylabel('Count')
    ax.set_title(title)
    ax.set_xticks(x + width * (len(data) - 1) / 2)
    ax.set_xticklabels(models)
    ax.legend()

    plt.tight_layout()
    plt.show()

# Create the plots
create_bar_plot(mac_pattern, 'mac pattern')
create_bar_plot(add2i_pattern, 'add2i pattern')
create_bar_plot(fusedmac_pattern, 'fusedmac pattern')

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for the plots
models = ['LeNet-5*', 'MobileNetV1', 'ResNet50', 'VGG16']
mac_pattern = {
    'add_count': [403907, 8168811, 740882470, 2298802039],
    'mul_count': [395737, 6868130, 625601717, 2281306146],
    'mul_add_count': [395580, 6662248, 624143510, 2279602152]
}
add2i_pattern = {
    'addi_count': [683213, 25449176, 1805151250, 6900499100],
    'addi_addi_count': [288536, 8151239, 530995267, 2288928117]
}
fusedmac_pattern = {
    'add_count': [403907, 8168811, 740882470, 2298802039],
    'addi_count': [683213, 25449176, 1805151250, 6900499100],
    'mul_count': [395737, 6868130, 625601717, 2281306146],
    'fusedmac_count': [288512, 6658048, 520880128, 2279571456]
}

# Function to create a bar plot with logarithmic scale
def create_bar_plot(data, title):
    x = np.arange(len(models))
    width = 0.35

    fig, ax = plt.subplots(figsize=(10, 6))

    # Create bars for each category
    for i, (category, values) in enumerate(data.items()):
        ax.bar(x + i * width, values, width, label=category)

    ax.set_ylabel('Count')
    ax.set_title(title)
    ax.set_xticks(x + width * (len(data) - 1) / 2)
    ax.set_xticklabels(models)
    ax.legend()

    # Set logarithmic scale for y-axis
    ax.set_yscale('log')

    plt.tight_layout()
    plt.show()

# Create the plots
create_bar_plot(mac_pattern, 'mac pattern')
create_bar_plot(add2i_pattern, 'add2i pattern')
create_bar_plot(fusedmac_pattern, 'fusedmac pattern')

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for the plots
models = ['LeNet-5*', 'MobileNetV1', 'ResNet50', 'VGG16']
mac_pattern = {
    'add_count': [403907, 8168811, 740882470, 2298802039],
    'mul_count': [395737, 6868130, 625601717, 2281306146],
    'mul_add_count': [395580, 6662248, 624143510, 2279602152]
}
add2i_pattern = {
    'addi_count': [683213, 25449176, 1805151250, 6900499100],
    'addi_addi_count': [288536, 8151239, 530995267, 2288928117]
}
fusedmac_pattern = {
    'add_count': [403907, 8168811, 740882470, 2298802039],
    'addi_count': [683213, 25449176, 1805151250, 6900499100],
    'mul_count': [395737, 6868130, 625601717, 2281306146],
    'fusedmac_count': [288512, 6658048, 520880128, 2279571456]
}

# Function to create and save a bar plot with logarithmic scale
def create_and_save_bar_plot(data, title, filename):
    x = np.arange(len(models))
    width = 0.2

    fig, ax = plt.subplots(figsize=(10, 6))  # Create a new figure for each plot

    # Create bars for each category
    for i, (category, values) in enumerate(data.items()):
        ax.bar(x + i * width, values, width, label=category)

    ax.set_ylabel('Count (Log Scale)', fontsize=18)  # Indicate log scale
    ax.set_title(title, fontsize=18, y=-0.2) # Title at the bottom
    ax.set_xticks(x + width * (len(data) - 1) / 2)
    ax.set_xticklabels(models, fontsize=18)
    ax.legend(fontsize=18)
    ax.set_yscale('log')
    ax.tick_params(axis='y', labelsize=18)
    ax.tick_params(axis='x', labelsize=18)

    plt.tight_layout()
    plt.savefig(filename, format='eps', bbox_inches='tight')  # Save the figure
    plt.show()


# Create and save the plots
create_and_save_bar_plot(mac_pattern, 'mac pattern', 'mac_pattern.eps')
create_and_save_bar_plot(add2i_pattern, 'add2i pattern', 'add2i_pattern.eps')
create_and_save_bar_plot(fusedmac_pattern, 'fusedmac pattern', 'fusedmac_pattern.eps')
# Out:
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for the plots
models = ['LeNet-5*', 'MobileNetV1', 'ResNet50', 'VGG16']
mac_pattern = {
    'add_count': [403907, 8168811, 740882470, 2298802039],
    'mul_count': [395737, 6868130, 625601717, 2281306146],
    'mul_add_count': [395580, 6662248, 624143510, 2279602152]
}
add2i_pattern = {
    'addi_count': [683213, 25449176, 1805151250, 6900499100],
    'addi_addi_count': [288536, 8151239, 530995267, 2288928117]
}
fusedmac_pattern = {
    'add_count': [403907, 8168811, 740882470, 2298802039],
    'addi_count': [683213, 25449176, 1805151250, 6900499100],
    'mul_count': [395737, 6868130, 625601717, 2281306146],
    'fusedmac_count': [288512, 6658048, 520880128, 2279571456]
}

# Total instruction counts for each model (replace with your actual data)
total_instruction_counts = [2604079, 82701885, 6370453927, 23000121441]

# Function to create and save a bar plot with normalization
def create_and_save_bar_plot(data, title, filename, total_counts):
    x = np.arange(len(models))
    width = 0.2

    fig, ax = plt.subplots(figsize=(10, 6))  # Create a new figure for each plot

    # Create bars for each category, normalized by total instruction count
    for i, (category, values) in enumerate(data.items()):
        normalized_values = [val / total_counts[j] for j, val in enumerate(values)]
        ax.bar(x + i * width, normalized_values, width, label=category)

    ax.set_ylabel('Normalized Instruction Count', fontsize=18)
    ax.set_title(title, fontsize=18, y=-0.2) # Title at the bottom
    ax.set_xticks(x + width * (len(data) - 1) / 2)
    ax.set_xticklabels(models, fontsize=18)
    ax.legend(fontsize=18, bbox_to_anchor=(1.05, 1), loc='upper left')

    # Remove logarithmic scale
    # ax.set_yscale('log')  # This line is removed

    ax.tick_params(axis='y', labelsize=18)
    ax.tick_params(axis='x', labelsize=18)

    plt.tight_layout()
    plt.savefig(filename, format='eps', bbox_inches='tight')  # Save the figure
    plt.show()


# Create and save the plots
create_and_save_bar_plot(mac_pattern, 'mac pattern', 'mac_pattern.eps', total_instruction_counts)
create_and_save_bar_plot(add2i_pattern, 'add2i pattern', 'add2i_pattern.eps', total_instruction_counts)
create_and_save_bar_plot(fusedmac_pattern, 'fusedmac pattern', 'fusedmac_pattern.eps', total_instruction_counts)
# Out:
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for the plots
models = ['LeNet-5*', 'MobileNetV1', 'ResNet50', 'VGG16']
mac_pattern = {
    'add_count': [403907, 8168811, 740882470, 2298802039],
    'mul_count': [395737, 6868130, 625601717, 2281306146],
    'mul_add_count': [395580, 6662248, 624143510, 2279602152]
}
add2i_pattern = {
    'addi_count': [683213, 25449176, 1805151250, 6900499100],
    'addi_addi_count': [288536, 8151239, 530995267, 2288928117]
}
fusedmac_pattern = {
    'add_count': [403907, 8168811, 740882470, 2298802039],
    'addi_count': [683213, 25449176, 1805151250, 6900499100],
    'mul_count': [395737, 6868130, 625601717, 2281306146],
    'fusedmac_count': [288512, 6658048, 520880128, 2279571456]
}

# Total instruction counts for each model (replace with your actual data)
total_instruction_counts = [1087147, 32346157, 2566936567, 9180631185]

# Function to create and save a bar plot with normalization
def create_and_save_bar_plot(data, title, filename, total_counts):
    x = np.arange(len(models))
    width = 0.2

    fig, ax = plt.subplots(figsize=(10, 6))  # Create a new figure for each plot

    # Create bars for each category, normalized by total instruction count
    max_y_value = 0  # Initialize to store maximum y-value
    for i, (category, values) in enumerate(data.items()):
        normalized_values = [val / total_counts[j] for j, val in enumerate(values)]
        ax.bar(x + i * width, normalized_values, width, label=category)
        max_y_value = max(max_y_value, max(normalized_values))  # Update max_y_value

    # Set y-axis limits to accommodate the legend
    ax.set_ylim(0, 1)  # Adjust 1.2 for extra space if needed

    ax.set_ylabel('Normalized Instruction Execution Count', fontsize=14)
    ax.set_title(title, fontsize=18, y=-0.2) # Title at the bottom
    ax.set_xticks(x + width * (len(data) - 1) / 2)
    ax.set_xticklabels(models, fontsize=18)
    ax.legend(fontsize=18, loc='upper right') # Legend at top right

    ax.tick_params(axis='y', labelsize=18)
    ax.tick_params(axis='x', labelsize=18)

    plt.tight_layout()
    plt.savefig(filename, format='eps', bbox_inches='tight')  # Save the figure
    plt.show()


# Create and save the plots
create_and_save_bar_plot(mac_pattern, 'mac pattern', 'mac_pattern.eps', total_instruction_counts)
create_and_save_bar_plot(add2i_pattern, 'add2i pattern', 'add2i_pattern.eps', total_instruction_counts)
create_and_save_bar_plot(fusedmac_pattern, 'fusedmac pattern', 'fusedmac_pattern.eps', total_instruction_counts)
# Out:
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for the plots
models = ['LeNet-5*', 'MobileNetV1', 'ResNet50', 'VGG16']
mac_pattern = {
    'add_count': [403907, 8168811, 740882470, 2298802039],
    'mul_count': [395737, 6868130, 625601717, 2281306146],
    'mul_add_count': [395580, 6662248, 624143510, 2279602152]
}
add2i_pattern = {
    'addi_count': [683213, 25449176, 1805151250, 6900499100],
    'addi_addi_count': [288536, 8151239, 530995267, 2288928117]
}
fusedmac_pattern = {
    'add_count': [403907, 8168811, 740882470, 2298802039],
    'addi_count': [683213, 25449176, 1805151250, 6900499100],
    'mul_count': [395737, 6868130, 625601717, 2281306146],
    'fusedmac_count': [288512, 6658048, 520880128, 2279571456]
}

# Total instruction counts for each model (replace with your actual data)
total_instruction_counts = [1087147, 32346157, 2566936567, 9180631185]

# Function to create and save a bar plot with normalization
def create_and_save_bar_plot(data, title, filename, total_counts):
    x = np.arange(len(models))
    width = 0.2

    fig, ax = plt.subplots(figsize=(10, 6))  # Create a new figure for each plot

    # Create bars for each category, normalized by total instruction count
    max_y_value = 0  # Initialize to store maximum y-value
    for i, (category, values) in enumerate(data.items()):
        normalized_values = [val / total_counts[j] for j, val in enumerate(values)]
        ax.bar(x + i * width, normalized_values, width, label=category)
        max_y_value = max(max_y_value, max(normalized_values))  # Update max_y_value

    # Set y-axis limits to accommodate the legend
    ax.set_ylim(0, 1)  # Adjust 1.2 for extra space if needed

    ax.set_ylabel('Normalized Instruction Execution Count', fontsize=14)
    ax.set_title(title, fontsize=18, y=-0.2) # Title at the bottom
    ax.set_xticks(x + width * (len(data) - 1) / 2)
    ax.set_xticklabels(models, fontsize=18)
    ax.legend(fontsize=18, loc='upper right') # Legend at top right

    ax.tick_params(axis='y', labelsize=18)
    ax.tick_params(axis='x', labelsize=18)

    plt.tight_layout()
    plt.savefig(filename, format='eps', bbox_inches='tight')  # Save the figure
    plt.show()


# Create and save the plots
create_and_save_bar_plot(mac_pattern, 'mac pattern', 'mac_pattern.eps', total_instruction_counts)
create_and_save_bar_plot(add2i_pattern, 'add2i pattern', 'add2i_pattern.eps', total_instruction_counts)
create_and_save_bar_plot(fusedmac_pattern, 'fusedmac pattern', 'fusedmac_pattern.eps', total_instruction_counts)
# Out:
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for the plots
models = ['LeNet-5*', 'MobileNetV1', 'ResNet50', 'VGG16', 'MobileNetV2', 'DenseNet121']
mac_pattern = {
    'add_count': [403907, 8168811, 740882470, 2298802039, 55516956, 684381607],
    'mul_count': [395737, 6868130, 625601717, 2281306146, 46780331, 468641445],
    'mul_add_count': [395580, 6662248, 624143510, 2279602152, 46175882, 465781894]
}
add2i_pattern = {
    'addi_count': [683213, 25449176, 1805151250, 6900499100, 161458027, 1445836399],
    'addi_addi_count': [288536, 8151239, 530995267, 2288928117, 53519109, 479631159]
}
fusedmac_pattern = {
    'add_count': [403907, 8168811, 740882470, 2298802039, 55516956, 684381607],
    'addi_count': [683213, 25449176, 1805151250, 6900499100, 161458027, 1445836399],
    'mul_count': [395737, 6868130, 625601717, 2281306146, 46780331, 468641445],
    'fusedmac_count': [288512, 6658048, 520880128, 2279571456, 45970176, 462653440]
}

# Total instruction counts for each model (replace with your actual data)
####total_instruction_counts = [1087147, 32346157, 2566936567, 9180631185]
total_instruction_counts = [2604079, 82701885, 6370453927, 23000121441, 536061024, 5027994525]

# Function to create and save a bar plot with normalization
def create_and_save_bar_plot(data, title, filename, total_counts):
    x = np.arange(len(models))
    width = 0.20

    fig, ax = plt.subplots(figsize=(10, 6))  # Create a new figure for each plot

    # Create bars for each category, normalized by total instruction count
    max_y_value = 0  # Initialize to store maximum y-value
    for i, (category, values) in enumerate(data.items()):
        normalized_values = [val / total_counts[j] for j, val in enumerate(values)]
        ax.bar(x + i * width, normalized_values, width, label=category)
        max_y_value = max(max_y_value, max(normalized_values))  # Update max_y_value

    # Set y-axis limits to accommodate the legend
    ax.set_ylim(0, 0.5)  # Adjust 1.2 for extra space if needed

    ax.set_ylabel('Normalized Instruction Execution Count', fontsize=14)
    ax.set_title(title, fontsize=20) # Title at the bottom
    ax.set_xticks(x + width * (len(data) - 1) / 2)
    ax.set_xticklabels(models, fontsize=18)
    #ax.legend(fontsize=18, loc='upper right') # Legend at top right
    ax.legend(fontsize=14, ncol=len(data), loc='upper center', bbox_to_anchor=(0.5, 1))

    ax.tick_params(axis='y', labelsize=18)
    ax.tick_params(axis='x', labelsize=18, rotation=45)

    plt.tight_layout()
    plt.savefig(filename, format='eps', bbox_inches='tight')  # Save the figure
    plt.show()


# Create and save the plots
create_and_save_bar_plot(mac_pattern, 'mac pattern', 'mac_pattern.eps', total_instruction_counts)
create_and_save_bar_plot(add2i_pattern, 'add2i pattern', 'add2i_pattern.eps', total_instruction_counts)
create_and_save_bar_plot(fusedmac_pattern, 'fusedmac pattern', 'fusedmac_pattern.eps', total_instruction_counts)
# Out:
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# Vishnu added

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for the plots
models = ['Bert-Tiny', 'MobileBert', 'MiniLM', 'Squeezebert']
sll2i_pattern = {
    'slli_count': [8523310,227937595,190425764,229321903],
    'slli_slli_count': [6292056,121639492,176160884,226492516]
}
add2_pattern = {
    'add_count': [142406190,5721739063,825059112,1513836848],
    'add_add_count': [33590514,515961544,743991190,1217547220]
}
add2i_pattern = {
    'addi_count': [343603612,16819689335,18399327703,21277146073],
    'addi_addi_count': [214122104,10791243204,12573276888,13954152984]
}

# Total instruction counts for each model (replace with your actual data)
total_instruction_counts = [1293943706,57540234319,56218215129,62960343399]

# Function to create and save a bar plot with normalization
def create_and_save_bar_plot(data, title, filename, total_counts):
    x = np.arange(len(models))
    width = 0.20

    fig, ax = plt.subplots(figsize=(10, 6))  # Create a new figure for each plot

    # Create bars for each category, normalized by total instruction count
    max_y_value = 0  # Initialize to store maximum y-value
    for i, (category, values) in enumerate(data.items()):
        normalized_values = [val / total_counts[j] for j, val in enumerate(values)]
        ax.bar(x + i * width, normalized_values, width, label=category)
        max_y_value = max(max_y_value, max(normalized_values))  # Update max_y_value

    # Set y-axis limits to accommodate the legend
    ax.set_ylim(0, 0.5)  # Adjust 1.2 for extra space if needed

    ax.set_ylabel('Normalized Instruction Execution Count', fontsize=14)
    ax.set_title(title, fontsize=20) # Title at the bottom
    ax.set_xticks(x + width * (len(data) - 1) / 2)
    ax.set_xticklabels(models, fontsize=18)
    #ax.legend(fontsize=18, loc='upper right') # Legend at top right
    ax.legend(fontsize=14, ncol=len(data), loc='upper center', bbox_to_anchor=(0.5, 1))

    ax.tick_params(axis='y', labelsize=18)
    ax.tick_params(axis='x', labelsize=18, rotation=45)

    plt.tight_layout()
    plt.savefig(filename, format='eps', bbox_inches='tight')  # Save the figure
    plt.show()


# Create and save the plots
create_and_save_bar_plot(sll2i_pattern, 'sll2i pattern', 'sll2i_pattern.eps', total_instruction_counts)
create_and_save_bar_plot(add2_pattern, 'add2 pattern', 'add2_pattern.eps', total_instruction_counts)
create_and_save_bar_plot(add2i_pattern, 'add2i pattern', 'add2i_pattern.eps', total_instruction_counts)
# Out:
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# #add2i pattern analysis

# %%
# !pip install adjustText

# %%
import pandas as pd
import sys
import matplotlib.pyplot as plt
from adjustText import adjust_text
import re

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Function to check if a pattern is covered
def is_covered(pattern):
    try:
        first, second = map(int, pattern.split('_'))  # Split pattern into two numbers
        return (0 <= first < 128) and (0 <= second < 256)
    except ValueError:
        return False

# %%
# Change this to the file with the pattern counts desired
file_path = "/content/drive/MyDrive/PhD_Works/instruction_report_mobilebert.csv"
df = pd.read_csv(file_path)
df.sort_values('cycle_count', inplace=True, ascending=False)
# Plot a bar chart
plt.figure(figsize=(10, 6))
top_N = 8
plt.bar(df.head(top_N)['pattern'], df.head(top_N)['cycle_count'], color='skyblue')

plt.xlabel('Pattern', fontsize=14)
plt.ylabel('Cycle Count', fontsize=12)

plt.xticks(rotation=0, fontsize=12)
plt.yticks(fontsize=12)
title = str('Cycle count of top ' + str(top_N) + ' most used patterns')
plt.title(title)
plt.tight_layout()
plt.savefig(str('cycle_count_bar.png'))
plt.show()
#====================================================
top_N = 10

# Get the top 10 patterns
top_10 = df.head(top_N)

others_count = df['cycle_count'].sum() - top_10['cycle_count'].sum()

# Create a new dataframe for the pie chart, including the "Others" category
pie_data = top_10[['pattern', 'cycle_count']].copy()
if others_count > 0:
    pie_data.loc[len(pie_data.index)] = ['Others', others_count]

from adjustText import adjust_text

plt.figure(figsize=(10, 6))
wedges, texts, autotexts = plt.pie(
    pie_data['cycle_count'],
    labels=pie_data['pattern'],
    autopct='%1.1f%%',
    colors=plt.cm.Paired.colors,
    startangle=140
)

# Adjust text positions
adjust_text(texts + autotexts, expand=(1.2, 1.5))

plt.title('Percentage Appearance of Patterns')
plt.savefig(str('percentage_pie.png'))
plt.show()


#====================================================
# Apply the function to categorize each pattern
df['covered'] = df['pattern'].apply(is_covered)

# Aggregate the cycle counts for covered and not covered patterns
coverage_counts = df.groupby('covered')['cycle_count'].sum()
print(coverage_counts)

# Calculate total cycle count
total_cycle_count = coverage_counts.sum()
print(total_cycle_count)

# Compute percentages
percentages = (coverage_counts / total_cycle_count) * 100
print(percentages)

labels = ['Covered', 'Not Covered']
values = [percentages.get(True, 0), percentages.get(False, 0)]

# Create the bar chart with percentages
plt.figure(figsize=(6, 6))
bars = plt.bar(labels, values, color=['green', 'red'])

# Add percentage labels on top of bars
# for bar, percent in zip(bars, values):
#     plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() -4, f'{percent:.1f}%', ha='center', fontsize=12)

plt.xlabel('Pattern Coverage', fontsize=12)
plt.ylabel('Percentage of Cycle Count', fontsize=12)
plt.title('Percentage of patterns covered by the add2i implementation range', fontsize=14)

plt.ylim(0, 100)
# Adjust fontsize
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.tight_layout()
plt.savefig(str('coverage_bar.png'))
plt.show()

display(df)
print(df['cycle_count'].sum())
# Out:
# covered
# False      90908088
# True     5333192462
# Name: cycle_count, dtype: int64
# 5424100550
# covered
# False     1.676003
# True     98.323997
# Name: cycle_count, dtype: float64
#     pattern  cycle_count  covered
# 7       4_4   5238703360     True
# 37   1_-256     80216064    False
# 13     4_32     50331648     True
# 29      1_4     24510464     True
# 18    4_128     12582912     True
# ..      ...          ...      ...
# 235  -1_152            0    False
# 237     2_8            0     True
# 238  -1_212            0    False
# 239    -1_8            0    False
# 240  212_-1            0    False
#
# [257 rows x 3 columns]
# 5424100550
